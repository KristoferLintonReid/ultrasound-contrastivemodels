# %% [markdown]
# <h1 align="center"> Baseline Models </h1>
#
# <br>
# <i> Import necessary libraries: <i>

# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import spearmanr
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier 
import matplotlib.pyplot as plt
import sklearn.metrics as mx
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, classification_report

from src.optimise import capitalize_j, format_case_id

from pybiomart import Server
import seaborn as sns

np.random.seed(2)

# %% [markdown]
# <i> Helper Functions: <i>

# %%
# def spearman_df_function(features, target, threshold):
#     feature_names = []
#     feature_correlations = []
    
#     column_names = features.columns.tolist()

#     for column in column_names:
#         corr, pval = spearmanr(features[column], target)
#         if (corr >= threshold):
#             feature_names.append(column)
#             feature_correlations.append(corr)

#     return feature_names, feature_correlations

def spearman_df_function(features, target, threshold):
    feature_names = []
    feature_correlations = []
    
    column_names = features.columns.tolist()

    for column in column_names:
        corr, pval = spearmanr(features[column], target)
        if (corr >= threshold and pval < 0.05):
            feature_names.append(column)
            feature_correlations.append(corr)

    return feature_names, feature_correlations

def modelPerformance(confMat):
    TN = confMat[0, 0]
    TP = confMat[1, 1]
    FP = confMat[0, 1]
    FN = confMat[1, 0]
    prec = TP / (TP + FP)
    rec = TP / (TP + FN)
    spec = TN / (TN + FP)
    fpr = FP / (TN + FP)
    f1 = 2 * (prec * rec) / (prec + rec)
    acc = (TP + TN) / (TP + FP + TN + FN)
    return (acc, prec, rec, spec, fpr, f1)

def printPerformance(confMat):
    acc, prec, rec, spec, fpr, f1 = modelPerformance(confMat)
    print("Accuracy = " "%.4f" % acc)
    print("Precision = " "%.4f" % prec)
    print("Recall = " "%.4f" % rec)
    print("Specificity = " "%.4f" % spec)
    print("False positive rate = " "%.4f" % fpr)
    print("F1-score = " "%.4f" % f1)
    np.set_printoptions(precision=2)
    print("Confusion matrix (%):")
    print(confMat/np.sum(confMat)*100)

def proximityMatrix(mdl, X, normalize=True):      
    endNode = mdl.apply(X)
    nTrees = endNode.shape[1]
    n = X.shape[0]
    proxMat = np.zeros((n,n))
    for k in range(0, nTrees):
        a = endNode[:,k]
        proxMat += 1*np.equal.outer(a, a)
    if normalize:
        proxMat = proxMat / nTrees
    return proxMat

# %% [markdown]
# ### Matching Samples for Analysis

# %%
# Step 1: Load RNA-Seq data
df_rna = pd.read_csv("/home/kryan24/MRes_Ultrasound/data/rna_counts/RNA_counts_141024.csv", header=None, low_memory=False)
df_rna_transposed = df_rna.transpose()
new_header = df_rna_transposed.iloc[1]
df_rna_transposed = df_rna_transposed[2:]
df_rna_transposed.columns = new_header
df_rna_transposed.rename(columns=lambda x: x.strip(), inplace=True) # Trim whitespaces

# Step 3: Filter RNA data for 'ENSG' columns
rna_cols = df_rna_transposed.filter(like='ENSG')

# Step 4: Load and merge image data
df_images = pd.read_excel("/home/kryan24/MRes_Ultrasound/data/metadata/RNA_Sample_Linking2.xlsx")
df_images.rename(columns=lambda x: x.strip(), inplace=True) # Trim whitespaces
df_images['Sample ID'] = df_images['Sample ID'].str.replace(' ', '_')
df_images["SURGICAL"] = df_images["SURGICAL"].str.strip() # Remove whitespaces from SURGICAL

df_merged = pd.merge(df_images, df_rna_transposed, left_on="Sample ID", right_on="Geneid")

df_merged_copy = df_merged

# Step 5: Correct data quality issues
df_merged["Extraction site"] = df_merged["Extraction site"].str.strip()
df_merged["Extraction site"] = df_merged["Extraction site"].str.lower()

# Step 6: Read the CSV file into a DataFrame 
df_radiomics = pd.read_csv("/home/kryan24/MRes_Ultrasound/data/metadata/radiomics_clinical_Barcroft_12_01_23.csv", low_memory=False)
# Remove first 2 columns
df_radiomics.drop(df_radiomics.columns[[0, 1]], axis=1, inplace=True)

# Filter columns
df_radiomics = df_radiomics.drop(df_radiomics.iloc[:, 3907:3950], axis=1)
df_radiomics["MAHCINE_CORECCTED"] = df_radiomics["MAHCINE_CORECCTED"].str.strip() # Remove whitespaces from MAHCINE_CORECCTED

# Step 7: Match radiomics data to metadata and filter DataFrame
df_radiomics_meta = df_merged[["Extraction site", "SURGICAL", "CASE ID", "CASE ID2"]]

# Step 8: Merge DataFrames
df_merged2 = pd.merge(df_radiomics_meta, df_radiomics, left_on="CASE ID", right_on="ID")

# Step 9: Correct data quality issues
df_merged2 = df_merged2.drop(["ID"], axis=1)

# Step 10: Keep the same samples for RNA as radiomics data
case_id_list = df_merged2["CASE ID"].tolist()
mask = df_merged["CASE ID"].isin(case_id_list)
df_merged = df_merged[mask]

# %%
# Check length of both paired sample dataframes
print("Number of rows in paired radiomics samples:", df_merged2.shape[0])
print("Number of rows in paired RNA samples:", df_merged.shape[0])
# Out:
# Number of rows in paired radiomics samples: 36
# Number of rows in paired RNA samples: 36

# %% [markdown]
# ### Pair Images and RNA data

# %%
# Filter radiomics data 
rad_cols = df_merged2.drop(["Extraction site", "SURGICAL", "CASE ID", "CASE ID2", "MAHCINE_CORECCTED"], axis=1)

# Step 1: Prepare image filenames and filter data
image_directory = "/home/kryan24/MRes_Ultrasound/CLIPRNA/images_matched"
image_filenames_rna = []
image_filenames_rad = []
rna_data_filtered = []
rad_data_filtered = []
surgical_rna = []
surgical_rad = []
sample_count_rna = 0 
sample_count_rad = 0 

rna_paired_id_list = []
rad_paired_id_list = []

# %%
for index, row in df_merged.iterrows():

    # Format and capitalize the CASE IDs
    case_id = capitalize_j(format_case_id(row['CASE ID']))
    case_id2 = capitalize_j(format_case_id(row['CASE ID2']))

    for file_name in os.listdir(image_directory):
            if file_name.endswith('.nii.gz') and 'seg' not in file_name:
                file_name_corrected = capitalize_j(file_name)  # Capitalize 'j' in the filename

                # Check if either case_id or case_id2 is a substring of the filename
                # Only check if the ID is non-empty
                if (case_id and case_id in file_name_corrected):
                    image_filenames_rna.append(file_name)
                    rna_data_filtered.append(
                        row[rna_cols.columns].apply(pd.to_numeric, errors='coerce').fillna(0)
                    )
                    surgical_rna.append(row["SURGICAL"])
                    rna_paired_id_list.append(case_id)
                    sample_count_rna += 1
                    break  # Only use the first matching image for each row

                if (case_id2 and case_id2 in file_name_corrected):
                    image_filenames_rna.append(file_name)
                    rna_data_filtered.append(
                        row[rna_cols.columns].apply(pd.to_numeric, errors='coerce').fillna(0)
                    )
                    surgical_rna.append(row["SURGICAL"])
                    rna_paired_id_list.append(case_id2)
                    sample_count_rna += 1
                    break  # Only use the first matching image for each row

print(f"Number of Samples: ", sample_count_rna)
# Out:
# Number of Samples:  29

# %%
for index, row in df_merged2.iterrows():

    # Format and capitalize the CASE IDs
    case_id = capitalize_j(format_case_id(row['CASE ID']))
    case_id2 = capitalize_j(format_case_id(row['CASE ID2']))

    for file_name in os.listdir(image_directory):
            if file_name.endswith('.nii.gz') and 'seg' not in file_name:
                file_name_corrected = capitalize_j(file_name)  # Capitalize 'j' in the filename

                # Check if either case_id or case_id2 is a substring of the filename
                # Only check if the ID is non-empty
                if (case_id and case_id in file_name_corrected):
                    image_filenames_rad.append(file_name)
                    rad_data_filtered.append(
                        row[rad_cols.columns].apply(pd.to_numeric, errors='coerce').fillna(0)
                    )
                    surgical_rad.append(row["SURGICAL"])
                    rad_paired_id_list.append(case_id)
                    sample_count_rad += 1
                    break  # Only use the first matching image for each row

                if (case_id2 and case_id2 in file_name_corrected):
                    image_filenames_rad.append(file_name)
                    rad_data_filtered.append(
                        row[rad_cols.columns].apply(pd.to_numeric, errors='coerce').fillna(0)
                    )
                    surgical_rad.append(row["SURGICAL"])
                    rad_paired_id_list.append(case_id2)
                    sample_count_rad += 1
                    break  # Only use the first matching image for each row

print(f"Number of Samples: ", sample_count_rad)
# Out:
# Number of Samples:  29

# %%
flag = (surgical_rna == surgical_rad)
print(f"Matching Diagnoses: ", flag)

flag2 = (image_filenames_rna == image_filenames_rad)
print(f"Matching Images: ", flag2)

flag3 = (rna_paired_id_list == rad_paired_id_list)
print(f"Matching IDs: ", flag3)
# Out:
# Matching Diagnoses:  True
# Matching Images:  True
# Matching IDs:  True

# %%
# Create DataFrame for surgical matching
match_dict = {"image_name": image_filenames_rad, "ID": rad_paired_id_list, "SURGICAL": surgical_rad} 
match_df = pd.DataFrame(match_dict)
match_df
# Out:
#            image_name     ID SURGICAL
# 0      12930_3.nii.gz  12930      B-S
# 1   13291_0010.nii.gz  13291      M-S
# 2      14023_3.nii.gz  14023      M-S
# 3      14056_3.nii.gz  14056      M-S
# 4      14654_3.nii.gz  14654      M-S
# 5      14024_2.nii.gz  14024      M-S
# 6   14984_0039.nii.gz  14984      M-S
# 7   16106_0022.nii.gz  16106      B-S
# 8   16134_0049.nii.gz  16134      M-S
# 9      16208_1.nii.gz  16208      B-S
# 10  16439_0004.nii.gz  16439      B-S
# 11  18638_0037.nii.gz  18638      M-S
# 12      187867.nii.gz  18786      M-S
# 13  18853_0020.nii.gz  18853      M-S
# 14  18852_0009.nii.gz  18852      B-S
# 15  24354_0019.nii.gz  24354      M-S
# 16  24903_0011.nii.gz  24903      M-S
# 17  25607_0005.nii.gz  25607      M-S
# 18  25827_0006.nii.gz  25827      M-S
# 19  25962_0006.nii.gz  25962      M-S
# 20     25961_2.nii.gz  25961      M-S
# 21     25970_2.nii.gz  25970      M-S
# 22   J630_0008.nii.gz   J630      M-S
# 23     26417_1.nii.gz  26417      M-S
# 24  26424_0007.nii.gz  26424      M-S
# 25    26425_-3.nii.gz  26425      B-S
# 26  26428_0020.nii.gz  26428      M-S
# 27  26604_0007.nii.gz  26604      M-S
# 28     26379_5.nii.gz  26379      M-S

# %% [markdown]
# ### Get Unpaired Images and RNA Data
# (_validation_)

# %%
# Step 6: Read the CSV file into a DataFrame 
df_radiomics = pd.read_csv("/home/kryan24/MRes_Ultrasound/data/metadata/radiomics_clinical_Barcroft_12_01_23.csv", low_memory=False)
# Remove first 2 columns
df_radiomics.drop(df_radiomics.columns[[0, 1]], axis=1, inplace=True)
# Filter columns
surg_placeholder = df_radiomics["SURGICAL"]
df_radiomics = df_radiomics.drop(df_radiomics.iloc[:, 3907:3950], axis=1)
df_radiomics["MAHCINE_CORECCTED"] = df_radiomics["MAHCINE_CORECCTED"].str.strip() # Remove whitespaces from MAHCINE_CORECCTED
df_radiomics.insert(0, "SURGICAL", surg_placeholder)
df_radiomics["SURGICAL"] = df_radiomics["SURGICAL"].str.strip() 
df_radiomics["SURGICAL"] = df_radiomics["SURGICAL"].replace(["B-NS", "B-NS -->THEATRE"], "B-S")
df_radiomics["SURGICAL"] = df_radiomics["SURGICAL"].replace(["M-NS"], "M-S")
df_radiomics = df_radiomics.loc[df_radiomics["SURGICAL"] != "NS"]
df_radiomics["ID"] = df_radiomics["ID"].astype(str)

# %%
rad_paired_id_list_noj = list(map(lambda x: "26246" if x == "J630" else x, rad_paired_id_list))
df_unpaired_rad = df_radiomics[~df_radiomics["ID"].isin(rad_paired_id_list_noj)]
df_unpaired_rna = df_merged_copy[~df_merged_copy["CASE ID"].isin(rna_paired_id_list) & ~df_merged_copy["CASE ID2"].isin(rna_paired_id_list)]

# %%
# Check length of both unpaired sample dataframes
print("Number of rows in unpaired radiomics samples:", df_unpaired_rad.shape[0])
print("Number of rows in unpaired RNA samples:", df_unpaired_rna.shape[0])
# Out:
# Number of rows in unpaired radiomics samples: 547
# Number of rows in unpaired RNA samples: 38

# %%
check1 = df_unpaired_rad["ID"].to_list()
check2 = rad_paired_id_list
set(check1) & set(check2)
# Out:
# set()

# %%
check1 = df_unpaired_rna["CASE ID"].to_list() + df_unpaired_rna["CASE ID2"].to_list()
check2 = rna_paired_id_list
set(check1) & set(check2)
# Out:
# set()

# %%
# Create DataFrame for surgical matching
match_rad_dict = {"CASE ID": df_unpaired_rad["ID"].astype("int64"), "SURGICAL": df_unpaired_rad["SURGICAL"]} 
match_rad_df = pd.DataFrame(match_rad_dict)
match_rad_df
# Out:
#      CASE ID SURGICAL
# 0      11935      B-S
# 1      12041      B-S
# 2      12165      B-S
# 3      12287      M-S
# 4      12665      M-S
# ..       ...      ...
# 572      756      B-S
# 573      757      B-S
# 574      759      B-S
# 575      760      M-S
# 576      765      B-S
#
# [547 rows x 2 columns]

# %%
# Create DataFrame for surgical matching
match_rna_dict = {"CASE ID": df_unpaired_rna["CASE ID"], "CASE ID2": df_unpaired_rna["CASE ID2"], "SURGICAL": df_unpaired_rna["SURGICAL"]} 
match_rna_df = pd.DataFrame(match_rna_dict)
match_rna_df
# Out:
#     CASE ID CASE ID2 SURGICAL
# 0     12930      NaN      B-S
# 1     13291      NaN      M-S
# 2     13750      NaN      M-S
# 3     14023      NaN      M-S
# 4     14056      NaN      M-S
# 5     14654      NaN      M-S
# 6     14024      NaN      M-S
# 7     14984      NaN      M-S
# 8     16106      NaN      B-S
# 9     16134      NaN      M-S
# 10    16208      NaN      B-S
# 11    16439      NaN      B-S
# 12    16937      NaN      M-S
# 13    18638      NaN      M-S
# 14    18786      NaN      M-S
# 15    18853      NaN      M-S
# 16    18852      NaN      B-S
# 17    24354     J303      M-S
# 18    24690     J341      M-S
# 19    24696     J347      M-S
# 20    24903     J374      M-S
# 21    25607     J398      M-S
# 22    25827     J432      M-S
# 23    25830     J435      M-S
# 24    25962     J453      M-S
# 25    25961     J452      M-S
# 26    25970     J461      M-S
# 27    26184     J478      M-S
# 28    26246     j486      M-S
# 30    26417     J517      M-S
# 31    26424     J524      M-S
# 32    26425     J525      B-S
# 33    26428     J528      M-S
# 34    26604     J547      M-S
# 35    26379     J516      M-S
# 36    26624     J567      M-S
# 37    28376     J623      M-S
# 38    28376     J613      M-S

# %% [markdown]
# ### Train-test Split

# %%
# Convert to DataFrame
rad_data_filtered = pd.DataFrame(rad_data_filtered)
# Convert to DataFrame
rna_data_filtered = pd.DataFrame(rna_data_filtered)

# %%
# Step 1: Split into train and test sets
rad_train, rad_test, rna_train, rna_test, surg_train, surg_test, img_train, img_test = train_test_split(rad_data_filtered, rna_data_filtered, surgical_rad, image_filenames_rad, test_size=0.2, random_state=2)

# %%
# Convert back to DataFrame
rad_train = pd.DataFrame(rad_train, columns=rad_data_filtered.columns)
rad_test = pd.DataFrame(rad_test, columns=rad_data_filtered.columns)
# Convert back to DataFrame
rna_train = pd.DataFrame(rna_train, columns=rna_data_filtered.columns)
rna_test = pd.DataFrame(rna_test, columns=rna_data_filtered.columns)

# %%
print(f"Number of RNA samples: ", rna_train.shape[0])
print(f"Number of radiomics samples: ", rad_train.shape[0])
print(f"Number of image filenames: ", len(img_train))
print(f"Number of diagnoses: ", len(surg_train))
print(f"Image filenames: ", img_train)
print(f"Diagnoses: ", surg_train)
# Out:
# Number of RNA samples:  23
# Number of radiomics samples:  23
# Number of image filenames:  23
# Number of diagnoses:  23
# Image filenames:  ['24903_0011.nii.gz', '14984_0039.nii.gz', '14056_3.nii.gz', '25962_0006.nii.gz', '26604_0007.nii.gz', '26428_0020.nii.gz', '187867.nii.gz', '14654_3.nii.gz', '16439_0004.nii.gz', '14024_2.nii.gz', '25970_2.nii.gz', '25607_0005.nii.gz', '14023_3.nii.gz', '16106_0022.nii.gz', '26425_-3.nii.gz', '26417_1.nii.gz', '25827_0006.nii.gz', '18638_0037.nii.gz', 'J630_0008.nii.gz', '26379_5.nii.gz', '18853_0020.nii.gz', '24354_0019.nii.gz', '16134_0049.nii.gz']
# Diagnoses:  ['M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'B-S', 'M-S', 'M-S', 'M-S', 'M-S', 'B-S', 'B-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S', 'M-S']

# %%
print(f"Number of RNA samples: ", rna_test.shape[0])
print(f"Number of radiomics samples: ", rad_test.shape[0])
print(f"Number of image filenames: ", len(img_test))
print(f"Number of diagnoses: ", len(surg_test))
print(f"Image filenames: ", img_test)
print(f"Diagnoses: ", surg_test)
# Out:
# Number of RNA samples:  6
# Number of radiomics samples:  6
# Number of image filenames:  6
# Number of diagnoses:  6
# Image filenames:  ['13291_0010.nii.gz', '12930_3.nii.gz', '18852_0009.nii.gz', '16208_1.nii.gz', '25961_2.nii.gz', '26424_0007.nii.gz']
# Diagnoses:  ['M-S', 'B-S', 'B-S', 'B-S', 'M-S', 'M-S']

# %% [markdown]
# # Radiomics Model
#
# ### Radiomics Tabular Data

# %%
# Scale radiomics samples
scaler_rad = StandardScaler()
rad_train_df = pd.DataFrame(scaler_rad.fit_transform(rad_train), columns=rad_data_filtered.columns)
rad_train_df.insert(0, "SURGICAL", surg_train)

rad_test_df = pd.DataFrame(scaler_rad.transform(rad_test), columns=rad_data_filtered.columns)
rad_test_df.insert(0, "SURGICAL", surg_test)

# %%
# Filter features selected using Spearman Rho
rad_all = rad_train_df.drop(["SURGICAL"], axis=1)
rad_class_cat = pd.Categorical(rad_train_df["SURGICAL"].astype("category")).codes
rad_feature_names, rad_feature_correlations = spearman_df_function(rad_all, rad_class_cat, 0.3)
# Out:
# /tmp/ipykernel_100813/4173520191.py:22: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, pval = spearmanr(features[column], target)

# %%
spearman_df = pd.DataFrame(
    {
        "Features": rad_feature_names,
        "Correlations": rad_feature_correlations
    }
)

spearman_df
# Out:
#                     Features  Correlations
# 0         GLSZM_ZoneHiGl_4gl      0.467099
# 1            GLCM_Varian_8gl      0.428174
# 2           GLCM_Varian_32gl      0.428174
# 3           GLCM_Varian_64gl      0.428174
# 4          GLCM_Varian_256gl      0.428174
# 5     GLSZM_ZoneHiGl_LLL_4gl      0.467099
# 6       NGTDM_Contra_LLL_8gl      0.428174
# 7   GLSZM_SzNonUnif_LLL_32gl      0.467099
# 8   GLSZM_SzVarianc_LLL_32gl      0.525487
# 9   GLSZM_SzNonUnif_LLL_64gl      0.428174
# 10    GLSZM_ZoneHiGl_LLH_4gl      0.467099
# 11      NGTDM_Contra_LLH_8gl      0.428174
# 12  GLSZM_SzNonUnif_LLH_32gl      0.467099
# 13  GLSZM_SzVarianc_LLH_32gl      0.525487
# 14  GLSZM_SzNonUnif_LLH_64gl      0.428174
# 15            FD_max_LHL_4gl      0.550482
# 16            FD_max_LHH_4gl      0.550482
# 17   GLSZM_SzVarianc_HHL_8gl      0.447637
# 18            FD_min_HHL_8gl      0.515883
# 19       GLCM_InfCo2_HHL_8gl      0.428174
# 20   GLSZM_SzVarianc_HHH_8gl      0.447637
# 21            FD_min_HHH_8gl      0.515883
# 22       GLCM_InfCo2_HHH_8gl      0.428174

# %%
# Store spearman features
spearman_rad = spearman_df["Features"].to_list()

# %%
# Seperating out the features
X_train_rad = rad_train_df.drop(["SURGICAL"], axis=1)
# Only keep the top features
X_train_rad = X_train_rad.loc[:, X_train_rad.columns.isin(spearman_rad)]
# Seperating out the target
y_train_rad = rad_train_df[["SURGICAL"]]

# %% [markdown]
# ### Fit Random Forest Model

# %%
# Set the random state for reproducibility
fit_rf_rad = RandomForestClassifier(n_estimators=1000, 
                                    random_state=2)

# %%
# Hyperparameter optimisation
param_dist = {"bootstrap": [True, False],
    "max_depth": [80, 90, 100, 110],
    "max_features": ["sqrt", "log2", 0.5, 0.7, None],
    "criterion": ["gini", "entropy"], 
    "class_weight": ["balanced", "balanced_subsample"]}

cv_rf_rad = GridSearchCV(fit_rf_rad, cv=3, param_grid=param_dist, verbose=3)

# %%
cv_rf_rad.fit(X_train_rad, y_train_rad.values.ravel())
print('Best Parameters using grid search: \n', 
      cv_rf_rad.best_params_)
# Out:
# Fitting 3 folds for each of 160 candidates, totalling 480 fits
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.875 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=log2;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.5;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.7;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=None;, score=0.875 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=None;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.5;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.7;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.7;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=0.875 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=0.875 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.875 total time=   0.7s
# ...
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=0.875 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=0.857 total time=   0.7s
# Best Parameters using grid search:
#  {'bootstrap': True, 'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 80, 'max_features': 'sqrt'}

# %% [markdown]
# `Best Parameters using grid search:
#  {'bootstrap': True, 'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 80, 'max_features': 'sqrt'}`

# %%
# Set best parameters given by grid search
fit_rf_rad.set_params(bootstrap = True,
                        criterion = "gini",
                        class_weight = "balanced",
                        max_depth = 80,
                        max_features = "sqrt")
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=80, n_estimators=1000,
#                        random_state=2)

# %% [markdown]
# ### Out of Bag Error Rate

# %%
fit_rf_rad.set_params(bootstrap = True,
                        n_estimators=100,
                        oob_score=True)

min_estimators = 10
max_estimators = 1000
min_oob_error = 1.0
min_index = 0

error_rate = {}

for i in range(min_estimators, max_estimators + 1):
    fit_rf_rad.set_params(n_estimators=i)
    fit_rf_rad.fit(X_train_rad, y_train_rad.values.ravel())

    oob_error = 1 - fit_rf_rad.oob_score_
    error_rate[i] = oob_error

    if min_oob_error > oob_error:
        min_oob_error = oob_error
        min_index = i

print("min_oob_error = ", min_oob_error)
print("min_index = ", min_index)
# Out:
# min_oob_error =  0.08695652173913049
# min_index =  32

# %%
fig, ax = plt.subplots(figsize=(10, 6))

num_estimators = list(error_rate.keys())
oob_error = list(error_rate.values())

plt.xlim(min_estimators, max_estimators)
plt.plot(num_estimators, oob_error)
plt.xlabel("n_estimators", fontsize=10)
plt.ylabel("OOB error rate", fontsize=10)
plt.title("OOB Error Rate Across Various Forest sizes (From 10 to 1000 trees)", fontsize=10)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

num_estimators = list(error_rate.keys())
oob_error = list(error_rate.values())

plt.xlim(min_estimators, 300)
plt.plot(num_estimators, oob_error)
plt.axhline(0.15, color="red", linestyle="--")
plt.axhline(0.11, color="red", linestyle="--")
plt.xlabel("n_estimators", fontsize=10)
plt.ylabel("OOB error rate", fontsize=10)
plt.title("OOB Error Rate Across Various Forest sizes (From 10 to 100 trees)", fontsize=10)
plt.show()

# %% [markdown]
# `n_estimators` = 150

# %% [markdown]
# ### Build Random Forest Model Using Best Parameters

# %%
# Create the classifier
fit_rf_rad.set_params(bootstrap = True,
                        n_estimators = 150, 
                        max_depth = 80,
                        max_features = "sqrt",
                        criterion= "gini",
                        class_weight = "balanced",
                        oob_score = True,
                        random_state = 2)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=80, n_estimators=150,
#                        oob_score=True, random_state=2)

# %%
# Fit the model to the training set
fit_rf_rad.fit(X_train_rad, y_train_rad)
# Out:
# /home/kryan24/miniconda3/envs/ovcan/lib/python3.12/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(class_weight='balanced', max_depth=80, n_estimators=150,
#                        oob_score=True, random_state=2)

# %% [markdown]
# ### Visualise Feature Importance

# %%
# Feature scores
feature_scores = pd.Series(fit_rf_rad.feature_importances_, index=X_train_rad.columns).sort_values(ascending=True)
feature_scores = feature_scores[feature_scores > 0]

# %%
fig, ax = plt.subplots(figsize=(5, 12))
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = True
plt.rcParams['axes.spines.top'] = True
plt.rcParams['axes.spines.bottom'] = True

ax.scatter(x=feature_scores, y=feature_scores.index, color="#17BECF")
miny, nexty, *_, maxy = ax.get_yticks()
eps = (nexty - miny) / 2 
ax.set_ylim(miny-eps, maxy+eps)
ax.set_xlim(0, max(feature_scores+0.01))
for x, y in zip(feature_scores, feature_scores.index):
    plt.hlines(y = y, xmin = 0, xmax = x-0.001, color="black") 
ax.tick_params(axis="both", which="major", labelsize=10)
ax.set_ylabel("Features", fontsize=12, labelpad=15)
ax.set_xlabel("Importance", fontsize=12, labelpad=15)

plt.show()

# %% [markdown]
# ### Evaluate Model
#
# #### Train

# %%
# Train 
y_train_rad_pred = pd.DataFrame(np.argmax(fit_rf_rad.oob_decision_function_,axis=1))
y_train_rad_pred.columns = ["SURGICAL"]
y_train_rad_pred["SURGICAL"] = y_train_rad_pred["SURGICAL"].map({1: "M-S", 0: "B-S"})
cmat = mx.confusion_matrix(y_train_rad, y_train_rad_pred)

# %%
printPerformance(cmat)
# Out:
# Accuracy = 0.9130
# Precision = 0.9500
# Recall = 0.9500
# Specificity = 0.6667
# False positive rate = 0.3333
# F1-score = 0.9500
# Confusion matrix (%):
# [[ 8.7   4.35]
#  [ 4.35 82.61]]

# %%
# Obtain the OOB error 
oob_error = 1 - fit_rf_rad.oob_score_ 
# Print the OOB error 
print(f'OOB error: {oob_error:.3f}')
# Out:
# OOB error: 0.087

# %%
# Print classification report for model
print(classification_report(y_train_rad, y_train_rad_pred))
# Out:
#               precision    recall  f1-score   support
#
#          B-S       0.67      0.67      0.67         3
#          M-S       0.95      0.95      0.95        20
#
#     accuracy                           0.91        23
#    macro avg       0.81      0.81      0.81        23
# weighted avg       0.91      0.91      0.91        23

# %%
cm = confusion_matrix(y_train_rad, y_train_rad_pred, labels=fit_rf_rad.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fit_rf_rad.classes_)
disp.plot()

# %% [markdown]
# #### Test

# %%
# Test

# Seperating out the features
X_test_rad = rad_test_df.drop(["SURGICAL"], axis=1)
# Only keep the top features
X_test_rad = X_test_rad.loc[:, X_test_rad.columns.isin(spearman_rad)]
# Seperating out the target
y_test_rad = rad_test_df[["SURGICAL"]]

y_test_rad_pred = fit_rf_rad.predict(X_test_rad)
cmat = mx.confusion_matrix(y_test_rad, y_test_rad_pred)

# %%
printPerformance(cmat)
# Out:
# Accuracy = 0.6667
# Precision = 0.6000
# Recall = 1.0000
# Specificity = 0.3333
# False positive rate = 0.6667
# F1-score = 0.7500
# Confusion matrix (%):
# [[16.67 33.33]
#  [ 0.   50.  ]]

# %%
# Obtain the OOB error 
oob_error = 1 - fit_rf_rad.oob_score_ 
# Print the OOB error 
print(f'OOB error: {oob_error:.3f}')
# Out:
# OOB error: 0.087

# %%
# Print classification report for model
print(classification_report(y_test_rad, y_test_rad_pred))
# Out:
#               precision    recall  f1-score   support
#
#          B-S       1.00      0.33      0.50         3
#          M-S       0.60      1.00      0.75         3
#
#     accuracy                           0.67         6
#    macro avg       0.80      0.67      0.62         6
# weighted avg       0.80      0.67      0.62         6

# %%
cm = confusion_matrix(y_test_rad, y_test_rad_pred, labels=fit_rf_rad.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fit_rf_rad.classes_)
disp.plot()

# %% [markdown]
# #### Validation (Unpaired Data)

# %%
rad_col_list = list(rad_train.columns.values)
rad_val = df_unpaired_rad.loc[:, df_unpaired_rad.columns.isin(rad_col_list)]
surg_val = df_unpaired_rad["SURGICAL"].to_list()

# Scale radiomics sample counts
rad_val_df = pd.DataFrame(scaler_rad.transform(rad_val), columns=rad_data_filtered.columns)
rad_val_df.insert(0, "SURGICAL", surg_val)

# %%
# Validation

# Seperating out the features
X_val_rad = rad_val_df.drop(["SURGICAL"], axis=1)
# Only keep the top features
X_val_rad = X_val_rad.loc[:, X_val_rad.columns.isin(spearman_rad)]
# Seperating out the target
y_val_rad = rad_val_df[["SURGICAL"]]

y_val_rad_pred = fit_rf_rad.predict(X_val_rad)
cmat = mx.confusion_matrix(y_val_rad, y_val_rad_pred)

# %%
printPerformance(cmat)
# Out:
# Accuracy = 0.2431
# Precision = 0.1968
# Recall = 0.9083
# Specificity = 0.0776
# False positive rate = 0.9224
# F1-score = 0.3235
# Confusion matrix (%):
# [[ 6.22 73.86]
#  [ 1.83 18.1 ]]

# %%
# Obtain the OOB error 
oob_error = 1 - fit_rf_rad.oob_score_ 
# Print the OOB error 
print(f'OOB error: {oob_error:.3f}')
# Out:
# OOB error: 0.087

# %%
# Print classification report for model
print(classification_report(y_val_rad, y_val_rad_pred))
# Out:
#               precision    recall  f1-score   support
#
#          B-S       0.77      0.08      0.14       438
#          M-S       0.20      0.91      0.32       109
#
#     accuracy                           0.24       547
#    macro avg       0.48      0.49      0.23       547
# weighted avg       0.66      0.24      0.18       547

# %%
cm = confusion_matrix(y_val_rad, y_val_rad_pred, labels=fit_rf_rad.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fit_rf_rad.classes_)
disp.plot()

# %% [markdown]
# ### Plot the ROC Curve

# %%
# Train data
disp = RocCurveDisplay.from_estimator(fit_rf_rad, X_train_rad, y_train_rad, pos_label='M-S', name="Train")

# Test data
disp = RocCurveDisplay.from_estimator(fit_rf_rad, X_test_rad, y_test_rad, pos_label='M-S', ax = disp.ax_, name="Validation")

# Validation data
disp = RocCurveDisplay.from_estimator(fit_rf_rad, X_val_rad, y_val_rad, pos_label='M-S', ax = disp.ax_, name="Test")

disp.ax_.set_title("ROC AUC curve for Radiomics Data");

# %%
# Train
y_pred_prob1 = fit_rf_rad.predict_proba(X_train_rad)[:, 1]
fpr1, tpr1, thresholds1 = roc_curve(y_train_rad, y_pred_prob1, pos_label="M-S")
auc1 = roc_auc_score(y_train_rad, y_pred_prob1)

# Test
y_pred_prob2 = fit_rf_rad.predict_proba(X_test_rad)[:, 1]
fpr2, tpr2, thresholds2 = roc_curve(y_test_rad, y_pred_prob2, pos_label="M-S")
auc2 = roc_auc_score(y_test_rad, y_pred_prob2)

# Validate
y_pred_prob3 = fit_rf_rad.predict_proba(X_val_rad)[:, 1]
fpr3, tpr3, thresholds3 = roc_curve(y_val_rad, y_pred_prob3, pos_label="M-S")
auc3 = roc_auc_score(y_val_rad, y_pred_prob3)

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr1, tpr1, label="Train (AUC = %0.2f)" % auc1)
plt.plot(fpr2, tpr2, label="Validation (AUC = %0.2f)" % auc2)
plt.plot(fpr3, tpr3, label="Test (AUC = %0.2f)" % auc3)

plt.legend()
plt.xlabel("False Positive Rate (Positive Label: M-S)")
plt.ylabel("True Positive Rate (Positive Label: M-S)")
plt.title('ROC AUC Curve for Radiomics Data')
plt.show()

# %% [markdown]
# # RNA Model
#
# ### RNA Tabular Data

# %%
# Scale RNA sample counts
scaler_rna = StandardScaler()
rna_train_df = pd.DataFrame(scaler_rna.fit_transform(rna_train), columns=rna_data_filtered.columns)
rna_train_df.insert(0, "SURGICAL", surg_train)

rna_test_df = pd.DataFrame(scaler_rna.transform(rna_test), columns=rna_data_filtered.columns)
rna_test_df.insert(0, "SURGICAL", surg_test)

# %%
# Filter features selected using Spearman Rho
rna_all = rna_train_df.drop(["SURGICAL"], axis=1)
rna_class_cat = pd.Categorical(rna_train_df["SURGICAL"].astype("category")).codes
rna_feature_names, rna_feature_correlations = spearman_df_function(rna_all, rna_class_cat, 0.5)
# Out:
# /tmp/ipykernel_100813/4173520191.py:22: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, pval = spearmanr(features[column], target)

# %%
spearman_df = pd.DataFrame(
    {
        "Features": rna_feature_names,
        "Correlations": rna_feature_correlations
    }
)

spearman_df
# Out:
#             Features  Correlations
# 0    ENSG00000189280      0.558978
# 1    ENSG00000163873      0.536678
# 2    ENSG00000143185      0.500767
# 3    ENSG00000162782      0.506525
# 4    ENSG00000197472      0.528498
# ..               ...           ...
# 240  ENSG00000161091      0.506024
# 241  ENSG00000225335      0.545354
# 242  ENSG00000242114      0.525487
# 243  ENSG00000128218      0.557859
# 244  ENSG00000183250      0.584018
#
# [245 rows x 2 columns]

# %%
# Store spearman features
spearman_rna = spearman_df["Features"].to_list()

# %%
# Seperating out the features
X_train_rna = rna_train_df.drop(["SURGICAL"], axis=1)
# Only keep the top features
X_train_rna = X_train_rna.loc[:, X_train_rna.columns.isin(spearman_rna)]
# Seperating out the target
y_train_rna = rna_train_df[["SURGICAL"]]

# %% [markdown]
# ### Fit Random Forest Model

# %%
# Set the random state for reproducibility
fit_rf_rna = RandomForestClassifier(n_estimators=1000, 
                                    random_state=2)

# %%
# Hyperparameter optimisation
param_dist = {"bootstrap": [True, False],
    "max_depth": [80, 90, 100, 110],
    "max_features": ["sqrt", "log2", 0.5, 0.7, None],
    "criterion": ["gini", "entropy"], 
    "class_weight": ["balanced", "balanced_subsample"]}

cv_rf_rna = GridSearchCV(fit_rf_rna, cv=3, param_grid=param_dist, verbose=3)

# %%
cv_rf_rna.fit(X_train_rna, y_train_rna.values.ravel())
print('Best Parameters using grid search: \n', 
      cv_rf_rna.best_params_)
# Out:
# Fitting 3 folds for each of 160 candidates, totalling 480 fits
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   1.4s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   1.4s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   1.4s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   1.7s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=log2;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.5;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=0.7;, score=0.857 total time=   1.4s
# [CV 1/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced, criterion=entropy, max_depth=110, max_features=None;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   1.3s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   1.3s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   1.3s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   1.5s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.6s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.7s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   1.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   1.5s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.6s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.6s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.7s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   1.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   1.5s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.6s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.7s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   1.9s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   1.2s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.857 total time=   1.2s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   1.4s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=0.857 total time=   1.5s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.5s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=0.857 total time=   1.6s
# [CV 1/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.6s
# [CV 2/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.7s
# [CV 3/3] END bootstrap=True, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=0.857 total time=   1.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=False, class_weight=balanced, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# ...
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=80, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=90, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=100, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=1.000 total time=   0.8s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.5;, score=0.857 total time=   0.8s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=0.7;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=gini, max_depth=110, max_features=None;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=80, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=90, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=100, max_features=None;, score=0.857 total time=   1.1s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=sqrt;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=1.000 total time=   0.7s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=log2;, score=0.857 total time=   0.7s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=1.000 total time=   0.9s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.5;, score=0.857 total time=   0.9s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=1.000 total time=   1.0s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=0.7;, score=0.857 total time=   1.0s
# [CV 1/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.1s
# [CV 2/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=1.000 total time=   1.1s
# [CV 3/3] END bootstrap=False, class_weight=balanced_subsample, criterion=entropy, max_depth=110, max_features=None;, score=0.857 total time=   1.1s
# Best Parameters using grid search:
#  {'bootstrap': True, 'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 80, 'max_features': 'sqrt'}

# %% [markdown]
# `Best Parameters using grid search:
#  {'bootstrap': True, 'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 80, 'max_features': 'sqrt'}`

# %%
# Set best parameters given by grid search
fit_rf_rna.set_params(bootstrap = True,
                        criterion = "gini",
                        class_weight = "balanced",
                        max_depth = 80,
                        max_features = "sqrt")
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=80, n_estimators=1000,
#                        random_state=2)

# %% [markdown]
# ### Out of Bag Error Rate

# %%
fit_rf_rna.set_params(n_estimators=100,
                        oob_score=True)

min_estimators = 10
max_estimators = 1000
min_oob_error = 1.0
min_index = 0

error_rate = {}

for i in range(min_estimators, max_estimators + 1):
    fit_rf_rna.set_params(n_estimators=i)
    fit_rf_rna.fit(X_train_rna, y_train_rna.values.ravel())

    oob_error = 1 - fit_rf_rna.oob_score_
    error_rate[i] = oob_error

    if min_oob_error > oob_error:
        min_oob_error = oob_error
        min_index = i

print("min_oob_error = ", min_oob_error)
print("min_index = ", min_index)
# Out:
# min_oob_error =  0.08695652173913049
# min_index =  22

# %%
fig, ax = plt.subplots(figsize=(10, 6))

num_estimators = list(error_rate.keys())
oob_error = list(error_rate.values())

plt.xlim(min_estimators, max_estimators)
plt.plot(num_estimators, oob_error)
plt.xlabel("n_estimators", fontsize=10)
plt.ylabel("OOB error rate", fontsize=10)
plt.title("OOB Error Rate Across Various Forest sizes (From 10 to 1000 trees)", fontsize=10)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

num_estimators = list(error_rate.keys())
oob_error = list(error_rate.values())

plt.xlim(min_estimators, 100)
plt.plot(num_estimators, oob_error)
plt.axhline(0.13, color="red", linestyle="--")
plt.axhline(0.105, color="red", linestyle="--")
plt.xlabel("n_estimators", fontsize=10)
plt.ylabel("OOB error rate", fontsize=10)
plt.title("OOB Error Rate Across Various Forest sizes (From 10 to 100 trees)", fontsize=10)
plt.show()

# %% [markdown]
# `n_estimators` = 70

# %% [markdown]
# ### Build Random Forest Model Using Best Parameters

# %%
# Create the classifier
fit_rf_rna.set_params(bootstrap = True,
                        n_estimators = 70, 
                        max_depth = 80,
                        max_features = "sqrt",
                        criterion= "gini",
                        class_weight = "balanced",
                        oob_score = True,
                        random_state = 2)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=80, n_estimators=70,
#                        oob_score=True, random_state=2)

# %%
# Fit the model to the training set
fit_rf_rna.fit(X_train_rna, y_train_rna)
# Out:
# /home/kryan24/miniconda3/envs/ovcan/lib/python3.12/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(class_weight='balanced', max_depth=80, n_estimators=70,
#                        oob_score=True, random_state=2)

# %% [markdown]
# ### Visualise Feature Importance

# %%
# Feature scores
feature_scores = pd.Series(fit_rf_rna.feature_importances_, index=X_train_rna.columns).sort_values(ascending=True)
feature_scores = feature_scores[feature_scores > 0]

# %%
fig, ax = plt.subplots(figsize=(5, 12))
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = True
plt.rcParams['axes.spines.top'] = True
plt.rcParams['axes.spines.bottom'] = True

ax.scatter(x=feature_scores, y=feature_scores.index, color="#17BECF")
miny, nexty, *_, maxy = ax.get_yticks()
eps = (nexty - miny) / 2 
ax.set_ylim(miny-eps, maxy+eps)
ax.set_xlim(0, max(feature_scores+0.01))
for x, y in zip(feature_scores, feature_scores.index):
    plt.hlines(y = y, xmin = 0, xmax = x-0.001, color="black") 
ax.tick_params(axis="both", which="major", labelsize=10)
ax.set_ylabel("Features", fontsize=12, labelpad=15)
ax.set_xlabel("Importance", fontsize=12, labelpad=15)

plt.show()

# %% [markdown]
# ### Evaluate Model
#
# #### Train

# %%
# Train 
y_train_rna_pred = pd.DataFrame(np.argmax(fit_rf_rna.oob_decision_function_,axis=1))
y_train_rna_pred.columns = ["SURGICAL"]
y_train_rna_pred["SURGICAL"] = y_train_rna_pred["SURGICAL"].map({1: "M-S", 0: "B-S"})
cmat = mx.confusion_matrix(y_train_rna, y_train_rna_pred)

# %%
printPerformance(cmat)
# Out:
# Accuracy = 0.9130
# Precision = 0.9091
# Recall = 1.0000
# Specificity = 0.3333
# False positive rate = 0.6667
# F1-score = 0.9524
# Confusion matrix (%):
# [[ 4.35  8.7 ]
#  [ 0.   86.96]]

# %%
# Obtain the OOB error 
oob_error = 1 - fit_rf_rad.oob_score_ 
# Print the OOB error 
print(f'OOB error: {oob_error:.3f}')
# Out:
# OOB error: 0.087

# %%
# Print classification report for model
print(classification_report(y_train_rna, y_train_rna_pred))
# Out:
#               precision    recall  f1-score   support
#
#          B-S       1.00      0.33      0.50         3
#          M-S       0.91      1.00      0.95        20
#
#     accuracy                           0.91        23
#    macro avg       0.95      0.67      0.73        23
# weighted avg       0.92      0.91      0.89        23

# %%
cm = confusion_matrix(y_train_rna, y_train_rna_pred, labels=fit_rf_rna.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fit_rf_rna.classes_)
disp.plot()

# %% [markdown]
# #### Test

# %%
# Test

# Seperating out the features
X_test_rna = rna_test_df.drop(["SURGICAL"], axis=1)
# Only keep the top features
X_test_rna = X_test_rna.loc[:, X_test_rna.columns.isin(spearman_rna)]
# Seperating out the target
y_test_rna = rna_test_df[["SURGICAL"]]

y_test_rna_pred = fit_rf_rna.predict(X_test_rna)
cmat = mx.confusion_matrix(y_test_rna, y_test_rna_pred)

# %%
printPerformance(cmat)
# Out:
# Accuracy = 0.6667
# Precision = 0.6000
# Recall = 1.0000
# Specificity = 0.3333
# False positive rate = 0.6667
# F1-score = 0.7500
# Confusion matrix (%):
# [[16.67 33.33]
#  [ 0.   50.  ]]

# %%
# Obtain the OOB error 
oob_error = 1 - fit_rf_rad.oob_score_ 
# Print the OOB error 
print(f'OOB error: {oob_error:.3f}')
# Out:
# OOB error: 0.087

# %%
# Print classification report for model
print(classification_report(y_test_rna, y_test_rna_pred))
# Out:
#               precision    recall  f1-score   support
#
#          B-S       1.00      0.33      0.50         3
#          M-S       0.60      1.00      0.75         3
#
#     accuracy                           0.67         6
#    macro avg       0.80      0.67      0.62         6
# weighted avg       0.80      0.67      0.62         6

# %%
cm = confusion_matrix(y_test_rna, y_test_rna_pred, labels=fit_rf_rna.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fit_rf_rna.classes_)
disp.plot()

# %% [markdown]
# #### Validation (Unpaired Data)

# %%
rna_col_list = list(rna_train.columns.values)
rna_val = df_unpaired_rna.loc[:, df_unpaired_rna.columns.isin(rna_col_list)]
surg_val = df_unpaired_rna["SURGICAL"].to_list()

# Scale RNA sample counts
rna_val_df = pd.DataFrame(scaler_rna.transform(rna_val), columns=rna_data_filtered.columns)
rna_val_df.insert(0, "SURGICAL", surg_val)

# %%
# Validation

# Seperating out the features
X_val_rna = rna_val_df.drop(["SURGICAL"], axis=1)
# Only keep the top features
X_val_rna = X_val_rna.loc[:, X_val_rna.columns.isin(spearman_rna)]
# Seperating out the target
y_val_rna = rna_val_df[["SURGICAL"]]

y_val_rna_pred = fit_rf_rna.predict(X_val_rna)
cmat = mx.confusion_matrix(y_val_rna, y_val_rna_pred)

# %%
printPerformance(cmat)
# Out:
# Accuracy = 0.9474
# Precision = 0.9412
# Recall = 1.0000
# Specificity = 0.6667
# False positive rate = 0.3333
# F1-score = 0.9697
# Confusion matrix (%):
# [[10.53  5.26]
#  [ 0.   84.21]]

# %%
# Obtain the OOB error 
oob_error = 1 - fit_rf_rad.oob_score_ 
# Print the OOB error 
print(f'OOB error: {oob_error:.3f}')
# Out:
# OOB error: 0.087

# %%
# Print classification report for model
print(classification_report(y_val_rna, y_val_rna_pred))
# Out:
#               precision    recall  f1-score   support
#
#          B-S       1.00      0.67      0.80         6
#          M-S       0.94      1.00      0.97        32
#
#     accuracy                           0.95        38
#    macro avg       0.97      0.83      0.88        38
# weighted avg       0.95      0.95      0.94        38

# %%
cm = confusion_matrix(y_val_rna, y_val_rna_pred, labels=fit_rf_rna.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=fit_rf_rna.classes_)
disp.plot()

# %% [markdown]
# ### Plot the ROC Curve

# %%
# Train data
disp = RocCurveDisplay.from_estimator(fit_rf_rna, X_train_rna, y_train_rna, pos_label='M-S', name="Train")

# Test data
disp = RocCurveDisplay.from_estimator(fit_rf_rna, X_test_rna, y_test_rna, pos_label='M-S', ax = disp.ax_, name="Validation")

# Validation data
disp = RocCurveDisplay.from_estimator(fit_rf_rna, X_val_rna, y_val_rna, pos_label='M-S', ax = disp.ax_, name="Test")

disp.ax_.set_title("ROC AUC curve for RNA Data");

# %%
# Train
y_pred_prob1 = fit_rf_rna.predict_proba(X_train_rna)[:, 1]
fpr1, tpr1, thresholds1 = roc_curve(y_train_rna, y_pred_prob1, pos_label="M-S")
auc1 = roc_auc_score(y_train_rna, y_pred_prob1)

# Test
y_pred_prob2 = fit_rf_rna.predict_proba(X_test_rna)[:, 1]
fpr2, tpr2, thresholds2 = roc_curve(y_test_rna, y_pred_prob2, pos_label="M-S")
auc2 = roc_auc_score(y_test_rna, y_pred_prob2)

# Validate
y_pred_prob3 = fit_rf_rna.predict_proba(X_val_rna)[:, 1]
fpr3, tpr3, thresholds3 = roc_curve(y_val_rna, y_pred_prob3, pos_label="M-S")
auc3 = roc_auc_score(y_val_rna, y_pred_prob3)

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr1, tpr1, label="Train (AUC = %0.2f)" % auc1)
plt.plot(fpr2, tpr2, label="Validation (AUC = %0.2f)" % auc2)
plt.plot(fpr3, tpr3, label="Test (AUC = %0.2f)" % auc3)

plt.legend()
plt.xlabel("False Positive Rate (Positive Label: M-S)")
plt.ylabel("True Positive Rate (Positive Label: M-S)")
plt.title('ROC AUC Curve for RNA Data')
plt.show()

# %% [markdown]
# ### Visualise Feature Importance

# %%
# Connect to Biomart server
server = Server(host="http://www.ensembl.org")
# Retrieving a ensembl genes mart
mart = server["ENSEMBL_MART_ENSEMBL"]
# Select homosapiens dataset
dataset = mart["hsapiens_gene_ensembl"]
# Retrieve the gene stable IDS and gene names from biomart
biomart_df = dataset.query(attributes=["ensembl_gene_id", "external_gene_name"])
biomart_df.head()
# Out:
#     Gene stable ID Gene name
# 0  ENSG00000210049     MT-TF
# 1  ENSG00000211459   MT-RNR1
# 2  ENSG00000210077     MT-TV
# 3  ENSG00000210082   MT-RNR2
# 4  ENSG00000209082    MT-TL1

# %%
X_train_rna_renamed = X_train_rna.copy(deep=True)

# Convert biomart_df to dictionary 
biomart_map = biomart_df.set_index("Gene name")
dict_genes = biomart_map["Gene stable ID"].to_dict()

# Convert ensmbl IDS to gene names
ensembl_ids_list = list(X_train_rna_renamed.columns)
gene_names = {v:k for k, v in dict_genes.items()}
genes_correct = [gene_names.get(item, item)  for item in ensembl_ids_list]

# Rename columns for RNA counts dataframe
X_train_rna_renamed.columns = genes_correct
X_train_rna_renamed.head()
# Out:
#        GJB5     GRIK3      XCL2     TDRD5    ZNF695      CR1L  MKNK1-AS1  \
# 0 -0.299804 -0.434138  0.599093 -0.508806 -0.314106 -0.237618  -0.589782
# 1 -0.299804 -0.434138 -0.628447  3.266208  3.544110 -0.230222   0.540634
# 2 -0.299804  2.654732 -0.628447 -0.697557 -0.365894 -0.259804   0.427592
# 3 -0.262430 -0.105743 -0.106743  0.661448 -0.521259 -0.156268   1.897132
# 4 -0.281117 -0.447144 -0.567070  0.573365 -0.210530 -0.230222  -0.928907
#
#    UBE2Q1-AS1  ECE1-AS1    FCGR1A  ...     CEBPG      CCNP  ENSG00000267174  \
# 0   -0.450596 -0.765162  0.483315  ... -0.106151 -0.471408        -0.303882
# 1   -0.450596  1.379486 -0.310703  ...  0.364936  0.196196        -0.595103
# 2    3.913074  0.559473 -0.320948  ... -0.456526 -0.527042        -0.595103
# 3    0.094862  1.821031 -0.205687  ... -0.306100 -0.174695         1.035732
# 4   -0.177867 -0.765162 -0.454138  ...  0.020132 -0.477589         0.628023
#
#        BCL3     TNNI3    MFSD12  ENSG00000225335     MTFP1    VPREB3  \
# 0 -0.587599 -0.651414 -0.237198         1.632304  0.104681 -0.176187
# 1 -0.072061  1.990765  0.055581         0.378782  0.299419 -0.231151
# 2 -0.637084 -0.513960  0.602531         0.253430 -0.603457 -0.226154
# 3  1.145140  0.219130  0.302245        -0.185303 -0.072353 -0.221157
# 4 -0.936953 -0.567414 -0.703715         0.441458 -0.373312 -0.236148
#
#    LINC01547
# 0  -0.557276
# 1   0.007103
# 2  -0.522621
# 3   1.937873
# 4  -0.433508
#
# [5 rows x 245 columns]

# %%
# Feature scores
feature_scores = pd.Series(fit_rf_rna.feature_importances_, index=X_train_rna_renamed.columns).sort_values(ascending=True)
feature_scores = feature_scores[feature_scores > 0]

# %%
fig, ax = plt.subplots(figsize=(5, 12))
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = True
plt.rcParams['axes.spines.top'] = True
plt.rcParams['axes.spines.bottom'] = True

ax.scatter(x=feature_scores, y=feature_scores.index, color="#17BECF")
miny, nexty, *_, maxy = ax.get_yticks()
eps = (nexty - miny) / 2 
ax.set_ylim(miny-eps, maxy+eps)
ax.set_xlim(0, max(feature_scores+0.01))
for x, y in zip(feature_scores, feature_scores.index):
    plt.hlines(y = y, xmin = 0, xmax = x-0.001, color="black") 
ax.tick_params(axis="both", which="major", labelsize=10)
ax.set_ylabel("Features", fontsize=12, labelpad=15)
ax.set_xlabel("Importance", fontsize=12, labelpad=15)

plt.show()

# %% [markdown]
# ### Visualise Feature Correlation

# %%
rna_cluster_data = X_train_rna_renamed.copy(deep=True)
rna_cluster_corr = rna_cluster_data.corr(numeric_only=True)

# %%
rna_cluster_corr
# Out:
#                      GJB5     GRIK3      XCL2     TDRD5    ZNF695      CR1L  \
# GJB5             1.000000 -0.091933  0.255433 -0.111826 -0.086228 -0.059471
# GRIK3           -0.091933  1.000000  0.062473  0.043281 -0.046575  0.086162
# XCL2             0.255433  0.062473  1.000000 -0.021890 -0.139424  0.832719
# TDRD5           -0.111826  0.043281 -0.021890  1.000000  0.712115 -0.059875
# ZNF695          -0.086228 -0.046575 -0.139424  0.712115  1.000000 -0.054205
# ...                   ...       ...       ...       ...       ...       ...
# MFSD12           0.288332  0.439810  0.580044  0.397645  0.028463  0.314402
# ENSG00000225335  0.201224  0.244373  0.038425  0.318881  0.200125 -0.121398
# MTFP1            0.164209 -0.120940  0.477980  0.285485  0.232371  0.416263
# VPREB3          -0.058678 -0.084118  0.262180 -0.095394 -0.098567 -0.039719
# LINC01547        0.000132 -0.020962 -0.008912  0.151357 -0.102213 -0.013180
#
#                  MKNK1-AS1  UBE2Q1-AS1  ECE1-AS1    FCGR1A  ...     CEBPG  \
# GJB5              0.062388    0.080956  0.045349 -0.106305  ...  0.102031
# GRIK3             0.366516    0.652009  0.055781 -0.040596  ... -0.089301
# XCL2             -0.040934   -0.032814 -0.014513  0.798666  ... -0.039941
# TDRD5             0.256648    0.006338  0.212192 -0.113562  ...  0.257578
# ZNF695            0.065077   -0.070607  0.225374 -0.122090  ...  0.540039
# ...                    ...         ...       ...       ...  ...       ...
# MFSD12            0.341679    0.445873  0.199237  0.367593  ... -0.033778
# ENSG00000225335   0.282543    0.440460  0.201822 -0.111605  ...  0.156377
# MTFP1             0.132043    0.132188  0.253332  0.327798  ...  0.166263
# VPREB3           -0.021496   -0.086855  0.283007  0.688395  ... -0.025871
# LINC01547         0.559979    0.069595  0.504892 -0.022311  ... -0.080740
#
#                      CCNP  ENSG00000267174      BCL3     TNNI3    MFSD12  \
# GJB5            -0.031989         0.444508  0.410280  0.255689  0.288332
# GRIK3            0.288952         0.212048  0.138521  0.523444  0.439810
# XCL2             0.060285         0.019398  0.163970  0.229495  0.580044
# TDRD5            0.073041         0.007833  0.193111  0.611817  0.397645
# ZNF695           0.226361        -0.075320 -0.083749  0.517554  0.028463
# ...                   ...              ...       ...       ...       ...
# MFSD12           0.052037         0.362903  0.633708  0.618277  1.000000
# ENSG00000225335  0.162322         0.697441  0.590071  0.444600  0.541405
# MTFP1           -0.034146         0.141199  0.317890  0.322195  0.600928
# VPREB3          -0.102719        -0.102610  0.255359 -0.146733  0.176770
# LINC01547       -0.105933         0.236323  0.369481  0.104015  0.300127
#
#                  ENSG00000225335     MTFP1    VPREB3  LINC01547
# GJB5                    0.201224  0.164209 -0.058678   0.000132
# GRIK3                   0.244373 -0.120940 -0.084118  -0.020962
# XCL2                    0.038425  0.477980  0.262180  -0.008912
# TDRD5                   0.318881  0.285485 -0.095394   0.151357
# ZNF695                  0.200125  0.232371 -0.098567  -0.102213
# ...                          ...       ...       ...        ...
# MFSD12                  0.541405  0.600928  0.176770   0.300127
# ENSG00000225335         1.000000  0.342914 -0.112929   0.093176
# MTFP1                   0.342914  1.000000 -0.018648   0.498124
# VPREB3                 -0.112929 -0.018648  1.000000  -0.040601
# LINC01547               0.093176  0.498124 -0.040601   1.000000
#
# [245 rows x 245 columns]

# %%
kws = dict(cbar_kws=dict(ticks=[0, 0.2, 0.4, 0.6, 0.8, 1], orientation='vertical'), figsize=(6, 6))

g = sns.clustermap(rna_cluster_corr,
                    metric="correlation", 
                    standard_scale=1, 
                    cmap="viridis", 
                    cbar_pos=(0.9, 0.8, .03, .4)) 

x0, _y0, _w, _h = g.cbar_pos
g.ax_cbar.set_position([0.9, 0.86, 0.1, 0.2])
plt.show()
# Out:
# /home/kryan24/miniconda3/envs/ovcan/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/kryan24/miniconda3/envs/ovcan/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
